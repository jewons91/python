# %% [markdown]
# ### 01 서울시 구별 CCTV 현황 분석
# **[학습목표]**
# 1. 서울시 구별 CCTV 데이터 파악, 인구대비 파악
# 2. 인구대비 평균치 파악, 구별 과부족 파악
# 3. pandas 사용법, 시각화(matplotlib)
# 4. 단순한 그래프로 시각화

# %%
import numpy as np
import pandas as pd

# %%
CCTV_Seoul = pd.read_csv('../data/01. CCTV_in_Seoul.csv', encoding='utf-8')
# CCTV_Seoul.head()
CCTV_Seoul.tail()
# Out:
#     기관명    소계  2013년도 이전  2014년  2015년  2016년
# 20  용산구  1624       1368    218    112    398
# 21  은평구  1873       1138    224    278    468
# 22  종로구  1002        464    314    211    630
# 23   중구   671        413    190     72    348
# 24  중랑구   660        509    121    177    109

# %%
print(CCTV_Seoul.index)
print(CCTV_Seoul.columns)
print(CCTV_Seoul.columns[-1])
print(CCTV_Seoul.values)
# Out:
# RangeIndex(start=0, stop=25, step=1)
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')
# 2016년
# [['강남구' 2780 1292 430 584 932]
#  ['강동구' 773 379 99 155 377]
#  ['강북구' 748 369 120 138 204]
#  ['강서구' 884 388 258 184 81]
#  ['관악구' 1496 846 260 390 613]
#  ['광진구' 707 573 78 53 174]
#  ['구로구' 1561 1142 173 246 323]
#  ['금천구' 1015 674 51 269 354]
#  ['노원구' 1265 542 57 451 516]
#  ['도봉구' 485 238 159 42 386]
#  ['동대문구' 1294 1070 23 198 579]
#  ['동작구' 1091 544 341 103 314]
#  ['마포구' 574 314 118 169 379]
#  ['서대문구' 962 844 50 68 292]
#  ['서초구' 1930 1406 157 336 398]
#  ['성동구' 1062 730 91 241 265]
#  ['성북구' 1464 1009 78 360 204]
#  ['송파구' 618 529 21 68 463]
#  ['양천구' 2034 1843 142 30 467]
#  ['영등포구' 904 495 214 195 373]
#  ['용산구' 1624 1368 218 112 398]
#  ['은평구' 1873 1138 224 278 468]
#  ['종로구' 1002 464 314 211 630]
#  ['중구' 671 413 190 72 348]
#  ['중랑구' 660 509 121 177 109]]

# %%
CCTV_Seoul.describe()
# Out:
#                 소계    2013년도 이전       2014년       2015년       2016년
# count    25.000000    25.000000   25.000000   25.000000   25.000000
# mean   1179.080000   764.760000  159.480000  205.200000  385.880000
# std     556.728983   415.510257  104.132976  137.877059  182.479981
# min     485.000000   238.000000   21.000000   30.000000   81.000000
# 25%     748.000000   464.000000   78.000000  103.000000  292.000000
# 50%    1015.000000   573.000000  142.000000  184.000000  377.000000
# 75%    1496.000000  1070.000000  218.000000  269.000000  467.000000
# max    2780.000000  1843.000000  430.000000  584.000000  932.000000

# %%
CCTV_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   기관명        25 non-null     object
#  1   소계         25 non-null     int64
#  2   2013년도 이전  25 non-null     int64
#  3   2014년      25 non-null     int64
#  4   2015년      25 non-null     int64
#  5   2016년      25 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.3+ KB

# %%
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]:'구별'})
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# 19  영등포구   904        495    214    195    373
# 20   용산구  1624       1368    218    112    398
# 21   은평구  1873       1138    224    278    468
# 22   종로구  1002        464    314    211    630
# 23    중구   671        413    190     72    348
# 24   중랑구   660        509    121    177    109

# %%
CCTV_Seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_Seoul_re1 = CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]:'구별'})

# %%
CCTV_Seoul_re1.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
POP_Seoul = \
    pd.read_excel('../data/01. population_in_Seoul.xls'
                  , header=2
                  , usecols='B,D,G,J,N'
                  )

# %%
POP_Seoul.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
POP_Seoul_re1 = POP_Seoul.rename(columns={
  POP_Seoul.columns[0]:'구별'
  , POP_Seoul.columns[1]:'인구수'
  , POP_Seoul.columns[2]:'한국인'
  , POP_Seoul.columns[3]:'외국인'
  , POP_Seoul.columns[4]:'고령자'
  }
                                 )

print(POP_Seoul_re1.columns)
# Out:
# Index(['구별', '인구수', '한국인', '외국인', '고령자'], dtype='object')

# %%
POP_Seoul_re1.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %% [markdown]
# ### Pandas 기초
# #### 컬럼 생성 : Series 다루기

# %%
data = [1,2,3,4,5]
series = pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data = [1,2,3,4,5]
index = ['a','b','c','d','e']
series = pd.Series(data=data, index=index)
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data_index = {
    'a': 1
    ,'b': 2
    ,'c': 3
    ,'d': 4
    ,'e': 5
}
series = pd.Series(data_index)
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data = 5
index = ['a', 'b', 'c']
series = pd.Series(data=data, index=index)
print(series)
# Out:
# a    5
# b    5
# c    5
# dtype: int64

# %%
series = pd.Series(data=[1, 2, 3]
                   , index=['a', 'b', 'c']
                   , name='sample_series'
                   , dtype='int8')
print(series)
print(series.values)
print(series.index)
print(series.name)
print(series.dtype)
# Out:
# a    1
# b    2
# c    3
# Name: sample_series, dtype: int8
# [1 2 3]
# Index(['a', 'b', 'c'], dtype='object')
# sample_series
# int8

# %%
series = pd.Series(data=[1, 2, 3], index=['a', 'b', 'c'])
print(series)
print(series + 1)
print(series * 2)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# a    2
# b    3
# c    4
# dtype: int64
# a    2
# b    4
# c    6
# dtype: int64

# %%
series = pd.Series(data=[1, 2, 3], index=['a', 'b', 'c'])
print(series)
print(series['b'])
print(series['b':'c'])
print(series[1:])
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# 2
# b    2
# c    3
# dtype: int64
# b    2
# c    3
# dtype: int64

# %%
series = pd.Series(data=[1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e'])
print(series)
print(series.apply(lambda x: x ** 2))
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a     1
# b     4
# c     9
# d    16
# e    25
# dtype: int64

# %%
print(series)
print(series.map({
    1: 'one'
    , 2: 'two'
    , 3: 'three'
}))
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a      one
# b      two
# c    three
# d      NaN
# e      NaN
# dtype: object

# %%
series = pd.Series([1, 2, 2, 3, 4])
print(series)
print('합 :', series.sum())
print('누적합 :', series.cumsum())
print('값의 빈도 :', series.value_counts())
print('평균 :', series.mean())
print('중앙값 :', series.median())
print('표준편차 :', series.std())
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# 4    4
# dtype: int64
# 합 : 12
# 누적합 : 0     1
# 1     3
# 2     5
# 3     8
# 4    12
# dtype: int64
# 값의 빈도 : 2    2
# 1    1
# 3    1
# 4    1
# Name: count, dtype: int64
# 평균 : 2.4
# 중앙값 : 2.0
# 표준편차 : 1.140175425099138

# %%
dates = pd.date_range('20240628', periods=7)
print(dates)
# Out:
# DatetimeIndex(['2024-06-28', '2024-06-29', '2024-06-30', '2024-07-01',
#                '2024-07-02', '2024-07-03', '2024-07-04'],
#               dtype='datetime64[ns]', freq='D')

# %%
series = pd.Series(data=[1, 2, 3, 4, 5, 6, 7], index=dates)
print(series)
print(series['20240701':'2024-07-03'])
# Out:
# 2024-06-28    1
# 2024-06-29    2
# 2024-06-30    3
# 2024-07-01    4
# 2024-07-02    5
# 2024-07-03    6
# 2024-07-04    7
# Freq: D, dtype: int64
# 2024-07-01    4
# 2024-07-02    5
# 2024-07-03    6
# Freq: D, dtype: int64

# %%
date_range = pd.date_range(start='2024-06-28', periods=10)
print(date_range)
# Out:
# DatetimeIndex(['2024-06-28', '2024-06-29', '2024-06-30', '2024-07-01',
#                '2024-07-02', '2024-07-03', '2024-07-04', '2024-07-05',
#                '2024-07-06', '2024-07-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
date_range = pd.date_range(start='2024-06-28', end='2024-10-11')
print(date_range)
# Out:
# DatetimeIndex(['2024-06-28', '2024-06-29', '2024-06-30', '2024-07-01',
#                '2024-07-02', '2024-07-03', '2024-07-04', '2024-07-05',
#                '2024-07-06', '2024-07-07',
#                ...
#                '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05',
#                '2024-10-06', '2024-10-07', '2024-10-08', '2024-10-09',
#                '2024-10-10', '2024-10-11'],
#               dtype='datetime64[ns]', length=106, freq='D')

# %%
date_range = pd.date_range(start='20240628', periods=10, freq='h')
print(date_range)
# Out:
# DatetimeIndex(['2024-06-28 00:00:00', '2024-06-28 01:00:00',
#                '2024-06-28 02:00:00', '2024-06-28 03:00:00',
#                '2024-06-28 04:00:00', '2024-06-28 05:00:00',
#                '2024-06-28 06:00:00', '2024-06-28 07:00:00',
#                '2024-06-28 08:00:00', '2024-06-28 09:00:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
date_range = pd.date_range(start='20240628', periods=3, freq='D')
print(date_range)
date_range = pd.date_range(start='20240628', periods=3, freq='B')
print(date_range)
date_range = pd.date_range(start='20240628', periods=3, freq='h')
print(date_range)
date_range = pd.date_range(start='20240628', periods=3, freq='min')
print(date_range)
date_range = pd.date_range(start='20240628', periods=3, freq='s')
print(date_range)
date_range = pd.date_range(start='20240628', periods=3, freq='ms')
print(date_range)
date_range = pd.date_range(start='20240628', periods=3, freq='W')
print(date_range)
date_range = pd.date_range(start='20240628', periods=3, freq='ME')
print(date_range)
date_range = pd.date_range(start='20240628', periods=3, freq='QE')
print(date_range)
date_range = pd.date_range(start='20240628', periods=3, freq='YE')
print(date_range)
# Out:
# DatetimeIndex(['2024-06-28', '2024-06-29', '2024-06-30'], dtype='datetime64[ns]', freq='D')
# DatetimeIndex(['2024-06-28', '2024-07-01', '2024-07-02'], dtype='datetime64[ns]', freq='B')
# DatetimeIndex(['2024-06-28 00:00:00', '2024-06-28 01:00:00',
#                '2024-06-28 02:00:00'],
#               dtype='datetime64[ns]', freq='h')
# DatetimeIndex(['2024-06-28 00:00:00', '2024-06-28 00:01:00',
#                '2024-06-28 00:02:00'],
#               dtype='datetime64[ns]', freq='min')
# DatetimeIndex(['2024-06-28 00:00:00', '2024-06-28 00:00:01',
#                '2024-06-28 00:00:02'],
#               dtype='datetime64[ns]', freq='s')
# DatetimeIndex([       '2024-06-28 00:00:00', '2024-06-28 00:00:00.001000',
#                '2024-06-28 00:00:00.002000'],
#               dtype='datetime64[ns]', freq='ms')
# DatetimeIndex(['2024-06-30', '2024-07-07', '2024-07-14'], dtype='datetime64[ns]', freq='W-SUN')
# DatetimeIndex(['2024-06-30', '2024-07-31', '2024-08-31'], dtype='datetime64[ns]', freq='ME')
# DatetimeIndex(['2024-06-30', '2024-09-30', '2024-12-31'], dtype='datetime64[ns]', freq='QE-DEC')
# DatetimeIndex(['2024-12-31', '2025-12-31', '2026-12-31'], dtype='datetime64[ns]', freq='YE-DEC')

# %%
import numpy as np
import pandas as pd
from datetime import datetime

now = datetime.now()
print(now)

dates = pd.date_range(now, periods=6)
print(dates)
# Out:
# 2024-07-02 17:22:26.413717
# DatetimeIndex(['2024-07-02 17:22:26.413717', '2024-07-03 17:22:26.413717',
#                '2024-07-04 17:22:26.413717', '2024-07-05 17:22:26.413717',
#                '2024-07-06 17:22:26.413717', '2024-07-07 17:22:26.413717'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.random.randn(6, 4)
# Out:
# array([[ 0.71866042, -1.36701944,  0.41638453,  1.11839752],
#        [ 0.32613767,  3.26960973, -1.20508392,  1.45266792],
#        [ 0.7185741 , -0.33394918, -0.47291233,  2.2704789 ],
#        [-0.57647947,  0.31568448, -0.12654054,  0.77785345],
#        [ 2.34711674, -0.42725651,  0.11436721, -0.51488165],
#        [-1.51076995, -2.24898279, -0.99378999,  0.10105969]])

# %%
df = pd.DataFrame(
      data = np.random.randn(6, 4)
    , index=dates
    , columns=['A', 'B', 'C', 'D']
)
df
# Out:
#                                    A         B         C         D
# 2024-07-02 17:22:26.413717 -0.190841 -2.248117  1.334087 -1.084076
# 2024-07-03 17:22:26.413717  0.356984 -0.486191  1.439227  0.248254
# 2024-07-04 17:22:26.413717 -0.364216  0.849384  1.524305  0.636789
# 2024-07-05 17:22:26.413717  0.811575 -0.010736 -0.406621 -1.127345
# 2024-07-06 17:22:26.413717  0.924298 -0.748793 -0.415744  1.400640
# 2024-07-07 17:22:26.413717 -0.875460  0.162551  0.006092  0.520295

# %%
df['A'], df['B']
# Out:
# (2024-07-02 17:22:26.413717   -0.190841
#  2024-07-03 17:22:26.413717    0.356984
#  2024-07-04 17:22:26.413717   -0.364216
#  2024-07-05 17:22:26.413717    0.811575
#  2024-07-06 17:22:26.413717    0.924298
#  2024-07-07 17:22:26.413717   -0.875460
#  Freq: D, Name: A, dtype: float64,
#  2024-07-02 17:22:26.413717   -2.248117
#  2024-07-03 17:22:26.413717   -0.486191
#  2024-07-04 17:22:26.413717    0.849384
#  2024-07-05 17:22:26.413717   -0.010736
#  2024-07-06 17:22:26.413717   -0.748793
#  2024-07-07 17:22:26.413717    0.162551
#  Freq: D, Name: B, dtype: float64)

# %%
df.head(1)
# Out:
#                                    A         B         C         D
# 2024-07-02 17:22:26.413717 -0.190841 -2.248117  1.334087 -1.084076

# %%
print(df.index)
# Out:
# DatetimeIndex(['2024-07-02 17:22:26.413717', '2024-07-03 17:22:26.413717',
#                '2024-07-04 17:22:26.413717', '2024-07-05 17:22:26.413717',
#                '2024-07-06 17:22:26.413717', '2024-07-07 17:22:26.413717'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.19084052, -2.24811683,  1.33408657, -1.08407558],
#        [ 0.35698351, -0.48619101,  1.43922719,  0.24825386],
#        [-0.36421582,  0.84938401,  1.52430531,  0.63678856],
#        [ 0.81157513, -0.01073578, -0.4066209 , -1.12734509],
#        [ 0.92429792, -0.74879289, -0.41574403,  1.40063959],
#        [-0.87546048,  0.16255126,  0.00609151,  0.52029524]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6 entries, 2024-07-02 17:22:26.413717 to 2024-07-07 17:22:26.413717
# Freq: D
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       6 non-null      float64
#  1   B       6 non-null      float64
#  2   C       6 non-null      float64
#  3   D       6 non-null      float64
# dtypes: float64(4)
# memory usage: 240.0 bytes

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.110390 -0.413650  0.580224  0.099093
# std    0.707504  1.055694  0.947938  1.008646
# min   -0.875460 -2.248117 -0.415744 -1.127345
# 25%   -0.320872 -0.683142 -0.303443 -0.750993
# 50%    0.083071 -0.248463  0.670089  0.384275
# 75%    0.697927  0.119230  1.412942  0.607665
# max    0.924298  0.849384  1.524305  1.400640

# %%
df
# Out:
#                                    A         B         C         D
# 2024-07-02 17:22:26.413717 -0.190841 -2.248117  1.334087 -1.084076
# 2024-07-03 17:22:26.413717  0.356984 -0.486191  1.439227  0.248254
# 2024-07-04 17:22:26.413717 -0.364216  0.849384  1.524305  0.636789
# 2024-07-05 17:22:26.413717  0.811575 -0.010736 -0.406621 -1.127345
# 2024-07-06 17:22:26.413717  0.924298 -0.748793 -0.415744  1.400640
# 2024-07-07 17:22:26.413717 -0.875460  0.162551  0.006092  0.520295

# %%
df.sort_values(by='B', ascending=False, axis=0)
# Out:
#                                    A         B         C         D
# 2024-07-04 17:22:26.413717 -0.364216  0.849384  1.524305  0.636789
# 2024-07-07 17:22:26.413717 -0.875460  0.162551  0.006092  0.520295
# 2024-07-05 17:22:26.413717  0.811575 -0.010736 -0.406621 -1.127345
# 2024-07-03 17:22:26.413717  0.356984 -0.486191  1.439227  0.248254
# 2024-07-06 17:22:26.413717  0.924298 -0.748793 -0.415744  1.400640
# 2024-07-02 17:22:26.413717 -0.190841 -2.248117  1.334087 -1.084076

# %%
df['A']
# Out:
# 2024-07-02 17:22:26.413717   -0.190841
# 2024-07-03 17:22:26.413717    0.356984
# 2024-07-04 17:22:26.413717   -0.364216
# 2024-07-05 17:22:26.413717    0.811575
# 2024-07-06 17:22:26.413717    0.924298
# 2024-07-07 17:22:26.413717   -0.875460
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                                    A         B         C         D
# 2024-07-02 17:22:26.413717 -0.190841 -2.248117  1.334087 -1.084076
# 2024-07-03 17:22:26.413717  0.356984 -0.486191  1.439227  0.248254
# 2024-07-04 17:22:26.413717 -0.364216  0.849384  1.524305  0.636789

# %%
df['2024-07-01 20:27:07.371863':'2024-07-03 20:27:07.371863']
# Out:
#                                    A         B         C         D
# 2024-07-02 17:22:26.413717 -0.190841 -2.248117  1.334087 -1.084076
# 2024-07-03 17:22:26.413717  0.356984 -0.486191  1.439227  0.248254

# %%
print(dates[0])
print(df.loc[dates[0]])
print(df.iloc[0])
# Out:
# 2024-07-02 17:22:26.413717
# A   -0.190841
# B   -2.248117
# C    1.334087
# D   -1.084076
# Name: 2024-07-02 17:22:26.413717, dtype: float64
# A   -0.190841
# B   -2.248117
# C    1.334087
# D   -1.084076
# Name: 2024-07-02 17:22:26.413717, dtype: float64

# %%
print(df)
print(df.loc[:, ['B', 'A']])
print(df.loc['2024-07-01 20:27:07.371863':'2024-07-06 20:27:07.371863', ['A', 'B']])
# Out:
#                                    A         B         C         D
# 2024-07-02 17:22:26.413717 -0.190841 -2.248117  1.334087 -1.084076
# 2024-07-03 17:22:26.413717  0.356984 -0.486191  1.439227  0.248254
# 2024-07-04 17:22:26.413717 -0.364216  0.849384  1.524305  0.636789
# 2024-07-05 17:22:26.413717  0.811575 -0.010736 -0.406621 -1.127345
# 2024-07-06 17:22:26.413717  0.924298 -0.748793 -0.415744  1.400640
# 2024-07-07 17:22:26.413717 -0.875460  0.162551  0.006092  0.520295
#                                    B         A
# 2024-07-02 17:22:26.413717 -2.248117 -0.190841
# 2024-07-03 17:22:26.413717 -0.486191  0.356984
# 2024-07-04 17:22:26.413717  0.849384 -0.364216
# 2024-07-05 17:22:26.413717 -0.010736  0.811575
# 2024-07-06 17:22:26.413717 -0.748793  0.924298
# 2024-07-07 17:22:26.413717  0.162551 -0.875460
#                                    A         B
# 2024-07-02 17:22:26.413717 -0.190841 -2.248117
# 2024-07-03 17:22:26.413717  0.356984 -0.486191
# 2024-07-04 17:22:26.413717 -0.364216  0.849384
# 2024-07-05 17:22:26.413717  0.811575 -0.010736
# 2024-07-06 17:22:26.413717  0.924298 -0.748793

# %%
data = {
      'Name': ['홍길동', '고길동', '마이꼴', '둘리', '희동']
    , 'Age': [20, 30, 20, 1000, 2]
    , 'Addr': ['울릉도', '서울', '서울', '별', '서울']
}
df = pd.DataFrame(data)
df
# Out:
#   Name   Age Addr
# 0  홍길동    20  울릉도
# 1  고길동    30   서울
# 2  마이꼴    20   서울
# 3   둘리  1000    별
# 4   희동     2   서울

# %%
df = df.set_index('Name')
df
# Out:
#        Age Addr
# Name
# 홍길동     20  울릉도
# 고길동     30   서울
# 마이꼴     20   서울
# 둘리    1000    별
# 희동       2   서울

# %%
df.loc['홍길동']
# Out:
# Age      20
# Addr    울릉도
# Name: 홍길동, dtype: object

# %%
df.loc[['홍길동', '마이꼴', '희동']]
# Out:
#       Age Addr
# Name
# 홍길동    20  울릉도
# 마이꼴    20   서울
# 희동      2   서울

# %%
df['Age'] > 20
# Out:
# Name
# 홍길동    False
# 고길동     True
# 마이꼴    False
# 둘리      True
# 희동     False
# Name: Age, dtype: bool

# %%
df[df['Age'] > 20]
# Out:
#        Age Addr
# Name
# 고길동     30   서울
# 둘리    1000    별

# %%
df.loc['고길동':'둘리']
# Out:
#        Age Addr
# Name
# 고길동     30   서울
# 마이꼴     20   서울
# 둘리    1000    별

# %%
df.loc[:, 'Age':'Addr']
# Out:
#        Age Addr
# Name
# 홍길동     20  울릉도
# 고길동     30   서울
# 마이꼴     20   서울
# 둘리    1000    별
# 희동       2   서울

# %%
df.iloc[0]
# Out:
# Age      20
# Addr    울릉도
# Name: 홍길동, dtype: object

# %%
df.iloc[[0, 2, 4]]
# Out:
#       Age Addr
# Name
# 홍길동    20  울릉도
# 마이꼴    20   서울
# 희동      2   서울

# %%
df.iloc[1:3]
# Out:
#       Age Addr
# Name
# 고길동    30   서울
# 마이꼴    20   서울

# %%
df.iloc[:, :]
# Out:
#        Age Addr
# Name
# 홍길동     20  울릉도
# 고길동     30   서울
# 마이꼴     20   서울
# 둘리    1000    별
# 희동       2   서울

# %%
print(df.loc['둘리', 'Addr'])
print(df.iloc[3, 1])
# Out:
# 별
# 별

# %%
df[df['Age'] > 20]
df[df.Age > 20]
# Out:
#        Age Addr
# Name
# 고길동     30   서울
# 둘리    1000    별

# %%
df2 = df.copy()
df2
# Out:
#        Age Addr
# Name
# 홍길동     20  울릉도
# 고길동     30   서울
# 마이꼴     20   서울
# 둘리    1000    별
# 희동       2   서울

# %%
df2['Gubun'] = ['가족', '친구', '회사', '기타', '가족']
df2
# Out:
#        Age Addr Gubun
# Name
# 홍길동     20  울릉도    가족
# 고길동     30   서울    친구
# 마이꼴     20   서울    회사
# 둘리    1000    별    기타
# 희동       2   서울    가족

# %%
df2[df2['Gubun'] == '가족']
df2['Gubun'].isin(['가족', '친구'])
# Out:
# Name
# 홍길동     True
# 고길동     True
# 마이꼴    False
# 둘리     False
# 희동      True
# Name: Gubun, dtype: bool

# %%
df2[df2['Gubun'].isin(['가족', '친구'])]
df2[df2.Gubun.isin(['가족', '친구'])]
# Out:
#       Age Addr Gubun
# Name
# 홍길동    20  울릉도    가족
# 고길동    30   서울    친구
# 희동      2   서울    가족

# %% [markdown]
# # Pandas 이용한 데이터 분석
# ### CCTV 현황 정리

# %%
CCTV_Seoul = pd.read_csv(
      '../data/01. CCTV_in_Seoul.csv'
    , encoding='utf-8'
)
CCTV_Seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]: '구별'}, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_Seoul.sort_values(by='소계', ascending=True).head()
# Out:
#      구별   소계  2013년도 이전  2014년  2015년  2016년
# 9   도봉구  485        238    159     42    386
# 12  마포구  574        314    118    169    379
# 17  송파구  618        529     21     68    463
# 24  중랑구  660        509    121    177    109
# 23   중구  671        413    190     72    348

# %%
CCTV_Seoul.sort_values(by='소계', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  2780       1292    430    584    932
# 18  양천구  2034       1843    142     30    467
# 14  서초구  1930       1406    157    336    398
# 21  은평구  1873       1138    224    278    468
# 20  용산구  1624       1368    218    112    398

# %%
CCTV_Seoul['최근증가율'] = (CCTV_Seoul['2016년'] \
                        + CCTV_Seoul['2015년'] \
                        + CCTV_Seoul['2014년']) \
                        / CCTV_Seoul['2013년도 이전'] * 100

# %%
CCTV_Seoul.sort_values(by='최근증가율', ascending=False).head()
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 22  종로구  1002        464    314    211    630  248.922414
# 9   도봉구   485        238    159     42    386  246.638655
# 12  마포구   574        314    118    169    379  212.101911
# 8   노원구  1265        542     57    451    516  188.929889
# 1   강동구   773        379     99    155    377  166.490765

# %%
POP_Seoul = \
    pd.read_excel('../data/01. population_in_Seoul.xls'
                  , header=2
                  , usecols='B, D, G, J, N'
                  )
POP_Seoul.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
POP_Seoul.rename(columns={
      POP_Seoul.columns[0]: '구별'
    , POP_Seoul.columns[1]: '인구수'
    , POP_Seoul.columns[2]: '한국인'
    , POP_Seoul.columns[3]: '외국인'
    , POP_Seoul.columns[4]: '고령자'
}
                 , inplace=True
                 )
POP_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
POP_Seoul.drop([0], axis=0, inplace=True)
POP_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자
# 1  종로구  162820.0  153589.0   9231.0  25425.0
# 2   중구  133240.0  124312.0   8928.0  20764.0
# 3  용산구  244203.0  229456.0  14747.0  36231.0
# 4  성동구  311244.0  303380.0   7864.0  39997.0
# 5  광진구  372164.0  357211.0  14953.0  42214.0

# %%
POP_Seoul['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구', nan],
#       dtype=object)

# %%
POP_Seoul['구별'].isnull()
# Out:
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# Name: 구별, dtype: bool

# %%
POP_Seoul[POP_Seoul['구별'].isnull()]
# Out:
#      구별  인구수  한국인  외국인  고령자
# 26  NaN  NaN  NaN  NaN  NaN

# %%
POP_Seoul.drop([26], axis=0, inplace=True)
POP_Seoul[POP_Seoul['구별'].isnull()]
# Out:
# Empty DataFrame
# Columns: [구별, 인구수, 한국인, 외국인, 고령자]
# Index: []

# %%
POP_Seoul.sort_values(by=['외국인'], ascending=False)
# Out:
#       구별       인구수       한국인      외국인      고령자
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 21   관악구  525515.0  507203.0  18312.0  68082.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 20   동작구  412520.0  400456.0  12064.0  56013.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 24   송파구  667483.0  660584.0   6899.0  72506.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 23   강남구  570500.0  565550.0   4950.0  63167.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 22   서초구  450310.0  445994.0   4316.0  51733.0
# 25   강동구  453233.0  449019.0   4214.0  54622.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0

# %%
POP_Seoul['외국인비율'] = POP_Seoul['외국인'] / POP_Seoul['인구수'] * 100
POP_Seoul['고령자비율'] = POP_Seoul['고령자'] / POP_Seoul['인구수'] * 100
POP_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 1  종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2   중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3  용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 4  성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 5  광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849

# %%
POP_Seoul.sort_values(by='외국인비율', ascending=False).head()
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 19  영등포구  402985.0  368072.0  34913.0  52413.0  8.663598  13.006191
# 18   금천구  255082.0  236353.0  18729.0  32970.0  7.342345  12.925255
# 17   구로구  447874.0  416487.0  31387.0  56833.0  7.007998  12.689506
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427

# %%
POP_Seoul.sort_values(by='외국인비율', ascending=True).head()
# Out:
#      구별       인구수       한국인     외국인      고령자     외국인비율      고령자비율
# 10  도봉구  348646.0  346629.0  2017.0  51312.0  0.578524  14.717507
# 11  노원구  569384.0  565565.0  3819.0  71941.0  0.670725  12.634883
# 15  양천구  479978.0  475949.0  4029.0  52975.0  0.839413  11.036964
# 23  강남구  570500.0  565550.0  4950.0  63167.0  0.867660  11.072217
# 12  은평구  494388.0  489943.0  4445.0  72334.0  0.899091  14.631019

# %%
POP_Seoul.sort_values(by='고령자비율', ascending=True).head()
# Out:
#      구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 24  송파구  667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 15  양천구  479978.0  475949.0   4029.0  52975.0  0.839413  11.036964
# 23  강남구  570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 5   광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849
# 22  서초구  450310.0  445994.0   4316.0  51733.0  0.958451  11.488308

# %%
print(CCTV_Seoul.head(3))
print(POP_Seoul.head(3))
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 0  강남구  2780       1292    430    584    932  150.619195
# 1  강동구   773        379     99    155    377  166.490765
# 2  강북구   748        369    120    138    204  125.203252
#     구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 1  종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2   중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3  용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427

# %% [markdown]
# # DataFrame 병합 연습

# %%
df1 = pd.DataFrame({
      'A': ['A0', 'A1', 'A2', 'A3']
    , 'B': ['B0', 'B1', 'B2', 'B3']
    , 'C': ['C0', 'C1', 'C2', 'C3']
    , 'D': ['D0', 'D1', 'D2', 'D3']
}
                   , index=[0, 1, 2, 3]
                   )

df2 = pd.DataFrame({
      'A': ['A4', 'A5', 'A6', 'A7']
    , 'B': ['B4', 'B5', 'B6', 'B7']
    , 'C': ['C4', 'C5', 'C6', 'C7']
    , 'D': ['D4', 'D5', 'D6', 'D7']
}
                   , index=[4, 5, 6, 7]
                   )

df3 = pd.DataFrame({
      'A': ['A8', 'A9', 'A10', 'A11']
    , 'B': ['B8', 'B9', 'B10', 'B11']
    , 'C': ['C8', 'C9', 'C10', 'C11']
    , 'D': ['D8', 'D9', 'D10', 'D11']
}
                   , index=[8, 9, 10, 11]
                   )

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result = pd.concat([df1, df2, df3], axis=0)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result = pd.concat([df1, df2, df3], keys=['df1', 'df2', 'df3'])
result
# Out:
#           A    B    C    D
# df1 0    A0   B0   C0   D0
#     1    A1   B1   C1   D1
#     2    A2   B2   C2   D2
#     3    A3   B3   C3   D3
# df2 4    A4   B4   C4   D4
#     5    A5   B5   C5   D5
#     6    A6   B6   C6   D6
#     7    A7   B7   C7   D7
# df3 8    A8   B8   C8   D8
#     9    A9   B9   C9   D9
#     10  A10  B10  C10  D10
#     11  A11  B11  C11  D11

# %%
result.index
# Out:
# MultiIndex([('df1',  0),
#             ('df1',  1),
#             ('df1',  2),
#             ('df1',  3),
#             ('df2',  4),
#             ('df2',  5),
#             ('df2',  6),
#             ('df2',  7),
#             ('df3',  8),
#             ('df3',  9),
#             ('df3', 10),
#             ('df3', 11)],
#            )

# %%
df4 = pd.DataFrame({
      'B': ['B2', 'B3', 'B6', 'B7']
    , 'D': ['D2', 'D3', 'D6', 'D7']
    , 'F': ['F2', 'F3', 'F6', 'F7']
}
                   , index=[2, 3, 6, 7]
                   )
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
df4, df1
# Out:
# (    B   D   F
#  2  B2  D2  F2
#  3  B3  D3  F3
#  6  B6  D6  F6
#  7  B7  D7  F7,
#      A   B   C   D
#  0  A0  B0  C0  D0
#  1  A1  B1  C1  D1
#  2  A2  B2  C2  D2
#  3  A3  B3  C3  D3)

# %%
result = pd.concat([df1, df4], axis=1, join='outer')
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result = pd.concat([df1, df4], axis=0)
result
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
result = pd.concat([df1, df4], axis=0, ignore_index=True)
result
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 4  NaN  B2  NaN  D2   F2
# 5  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
result = pd.concat(
      [df1, df4]
    , axis=1
    , join='outer'
    # , join_axes=[df1.index]
)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
left = pd.DataFrame({
      'key': ['k0', 'k4', 'k2', 'k3']
    , 'A': ['a0', 'a1', 'a2', 'a3']
    , 'B': ['b0', 'b1', 'b2', 'b3']
})

right = pd.DataFrame({
      'key': ['k0', 'k1', 'k2', 'k3']
    , 'C': ['c0', 'c1', 'c2', 'c3']
    , 'D': ['d0', 'd1', 'd2', 'd3']
})
left, right
# Out:
# (  key   A   B
#  0  k0  a0  b0
#  1  k4  a1  b1
#  2  k2  a2  b2
#  3  k3  a3  b3,
#    key   C   D
#  0  k0  c0  d0
#  1  k1  c1  d1
#  2  k2  c2  d2
#  3  k3  c3  d3)

# %%
pd.merge(left, right, on='key', how='inner')
# Out:
#   key   A   B   C   D
# 0  k0  a0  b0  c0  d0
# 1  k2  a2  b2  c2  d2
# 2  k3  a3  b3  c3  d3

# %%
pd.merge(left, right, on='key', how='outer')
# Out:
#   key    A    B    C    D
# 0  k0   a0   b0   c0   d0
# 1  k1  NaN  NaN   c1   d1
# 2  k2   a2   b2   c2   d2
# 3  k3   a3   b3   c3   d3
# 4  k4   a1   b1  NaN  NaN

# %%
pd.merge(left, right, on='key', how='left')
# Out:
#   key   A   B    C    D
# 0  k0  a0  b0   c0   d0
# 1  k4  a1  b1  NaN  NaN
# 2  k2  a2  b2   c2   d2
# 3  k3  a3  b3   c3   d3

# %%
pd.merge(left, right, on='key', how='right')
# Out:
#   key    A    B   C   D
# 0  k0   a0   b0  c0  d0
# 1  k1  NaN  NaN  c1  d1
# 2  k2   a2   b2  c2  d2
# 3  k3   a3   b3  c3  d3

# %% [markdown]
# # CCTV, 인구현황 병합, 분석

# %%
CCTV_Seoul.head(1), POP_Seoul.head(1)
# Out:
# (    구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
#  0  강남구  2780       1292    430    584    932  150.619195,
#      구별       인구수       한국인     외국인      고령자     외국인비율      고령자비율
#  1  종로구  162820.0  153589.0  9231.0  25425.0  5.669451  15.615404)

# %%
data_result = pd.merge(
      CCTV_Seoul
    , POP_Seoul
    , on='구별'
    , how='inner'
)
data_result.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율       인구수       한국인  \
# 0  강남구  2780       1292    430    584    932  150.619195  570500.0  565550.0
# 1  강동구   773        379     99    155    377  166.490765  453233.0  449019.0
# 2  강북구   748        369    120    138    204  125.203252  330192.0  326686.0
# 3  강서구   884        388    258    184     81  134.793814  603772.0  597248.0
# 4  관악구  1496        846    260    390    613  149.290780  525515.0  507203.0
#
#        외국인      고령자     외국인비율      고령자비율
# 0   4950.0  63167.0  0.867660  11.072217
# 1   4214.0  54622.0  0.929765  12.051638
# 2   3506.0  54813.0  1.061806  16.600342
# 3   6524.0  72548.0  1.080540  12.015794
# 4  18312.0  68082.0  3.484582  12.955291

# %%
del data_result['2013년도 이전']
del data_result['2014년']
del data_result['2015년']
del data_result['2016년']
data_result.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 1  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 2  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 3  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 4  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#        고령자비율
# 0  11.072217
# 1  12.051638
# 2  16.600342
# 3  12.015794
# 4  12.955291

# %%
data_result.set_index('구별', inplace=True)
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 강남구  11.072217
# 강동구  12.051638
# 강북구  16.600342
# 강서구  12.015794
# 관악구  12.955291

# %%
np.corrcoef(data_result['인구수'], data_result['소계'])
# Out:
# array([[1.        , 0.30634228],
#        [0.30634228, 1.        ]])

# %%
np.corrcoef(data_result['외국인'], data_result['소계'])
# Out:
# array([[ 1.        , -0.02378619],
#        [-0.02378619,  1.        ]])

# %%
np.corrcoef(data_result['고령자'], data_result['소계'])
# Out:
# array([[1.        , 0.25519598],
#        [0.25519598, 1.        ]])

# %% [markdown]
# ---
# ### 시각화
#
# ---

# %% [markdown]
# #### plot 종류
# 1. 라인플롯
# 2. 스캐터 플롯
# 3. 바 차트
# 4. 히스토그램
# 5. 박스 플롯
# 6. 컨투어 플롯
# 7. 서피스 플롯
# 8. 등등등

# %% [markdown]
# #### matplotlib 서브 패키지 : pyplot 시각화 처리

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
plt.plot([1, 2, 3, 4, 5, 6])
plt.show()

# %%
plt.figure(figsize=(5, 5))
plt.title('시각화연습')
# data = [1, 4, 9, 16]
# plt.plot(data)
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
from matplotlib import rcParams
import matplotlib.font_manager as fm

fpaths = fm.findSystemFonts()
font_names = []

for i in fpaths:
    f = fm.get_font(i)
    font_names.append(f.family_name)
    
print(font_names[:5])

for fn in font_names:
    if 'malgun' in fn.lower():
        print(fn)
# Out:
# ['Comic Sans MS', 'Lucida Fax', 'Segoe UI', 'Gill Sans MT', 'Webdings']
# Malgun Gothic
# Malgun Gothic
# Malgun Gothic

# %%
rcParams['font.family'] = 'Malgun Gothic'
rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(5, 5))
plt.title('라인그래프')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
t = np.arange(0, 12, 0.01)
y = np.sin(t)

# %%
plt.figure(figsize=(10, 6))
plt.plot(t, np.sin(t), label='sin')
plt.plot(t, np.cos(t), label='cos')
plt.grid()
plt.title('Example of sinewave')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.xlim(0, 2 * np.pi)
plt.ylim(-2, 2)
plt.show()

# %%
t = np.arange(0, 5, 0.5)
print(t)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5]

# %%
plt.figure(figsize=(10, 6))
plt.plot(t, t, 'r--')
plt.plot(t, t ** 2, 'bs')
plt.plot(t, t ** 3, 'gD')
plt.show()

# %%
t = [0, 1, 2, 3, 4, 5, 6]
y = [1, 4, 5, 8, 9, 5, 3]
plt.figure(figsize=(10, 6))
plt.plot(t, y, color='red'
         , linewidth=2
         , linestyle='dotted'
         , marker='o', markerfacecolor='w', markeredgecolor='b'
         , markeredgewidth=3)
plt.show()

# %%
t = np.arange(0, 10)
y = np.array([9, 8, 7, 9, 8, 3, 2, 4, 3, 4])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(t, y, marker='>')
plt.show()

# %%
colormap = t
plt.figure(figsize=(10, 6))
plt.scatter(t, y, marker='>', c=colormap)
plt.colorbar()
plt.show()

# %%
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 강남구  11.072217
# 강동구  12.051638
# 강북구  16.600342
# 강서구  12.015794
# 관악구  12.955291

# %%
data_result['소계'].plot(
    kind='barh'
    , grid=True
    , figsize=(5, 5)
)
# Out:
# <Axes: ylabel='구별'>

# %%
data_result['소계'].sort_values().plot(
    kind='barh'
    , grid=True
    , figsize=(5, 5)
)
# Out:
# <Axes: ylabel='구별'>

# %%
data_result['CCTV비율'] = data_result['소계'] / data_result['인구수'] * 100
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율    CCTV비율
# 구별
# 강남구  11.072217  0.487292
# 강동구  12.051638  0.170552
# 강북구  16.600342  0.226535
# 강서구  12.015794  0.146413
# 관악구  12.955291  0.284673

# %%
data_result['CCTV비율'].sort_values().plot(
    kind='barh'
    , grid=True
    , figsize=(5, 5)
)
# Out:
# <Axes: ylabel='구별'>

# %%
plt.figure(figsize=(4, 4))
plt.scatter(
      data_result['인구수']
    , data_result['소계']
    , s=50
)
plt.grid()
plt.title('인구대비 CCTV 개수')
plt.xlabel('인구수')
plt.ylabel('CCTV 개수')
plt.show()

# %% [markdown]
# - 데이터를 대표하는 직선 표시 (인구수와 CCTV 상관관계)
# - polyfit : 지정한 특정 차수의 다항의 계수 계산
#   - y = a * x + b => 계수 : a, b
# - polyfit : 계수를 사용한 실제 다항식 생성 (함수)
#   - a : 2, b : 3 => f(x) = 2 * x + 3

# %%
fp1 = np.polyfit(data_result['인구수'], data_result['소계'], deg=1)
fp1
# Out:
# array([1.30916415e-03, 6.45066497e+02])

# %%
func = np.poly1d(fp1)
func
# Out:
# poly1d([1.30916415e-03, 6.45066497e+02])

# %%
fx = np.linspace(100000, 700000, 100)

# %%
plt.figure(figsize=(10, 8))
plt.scatter(data_result['인구수'], data_result['소계'], s=50)
plt.plot(fx, func(fx), ls='dashed', lw=3, color='g')
plt.xlabel('인구수')
plt.ylabel('CCTV 개수')
plt.show()

# %%
data_result['오차'] = np.abs(data_result['소계'] - func(data_result['인구수']))

# %%
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율    CCTV비율           오차
# 구별
# 강남구  11.072217  0.487292  1388.055355
# 강동구  12.051638  0.170552   465.422892
# 강북구  16.600342  0.226535   329.342026
# 강서구  12.015794  0.146413   551.503155
# 관악구  12.955291  0.284673   162.948104

# %%
df_sort = data_result.sort_values(by='오차', ascending=False)
df_sort.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 송파구   618  104.347826  667483.0  660584.0   6899.0  72506.0  1.033584
# 양천구  2034   34.671731  479978.0  475949.0   4029.0  52975.0  0.839413
# 서초구  1930   63.371266  450310.0  445994.0   4316.0  51733.0  0.958451
# 용산구  1624   53.216374  244203.0  229456.0  14747.0  36231.0  6.038828
#
#          고령자비율    CCTV비율           오차
# 구별
# 강남구  11.072217  0.487292  1388.055355
# 송파구  10.862599  0.092587   900.911312
# 양천구  11.036964  0.423769   760.563512
# 서초구  11.488308  0.428594   695.403794
# 용산구  14.836427  0.665020   659.231690

# %%
plt.figure(figsize=(7, 5))
plt.scatter(
    data_result['인구수']
    , data_result['소계']
    , c=data_result['오차']
    , s=50
)
plt.plot(fx, func(fx), ls='dashed', lw=3, color='g')
for n in range(10):
    plt.text(
        df_sort['인구수'].iloc[n] * 1.02
        , df_sort['소계'].iloc[n] * 0.98
        , df_sort.index[n]
        , fontsize=10
    )
plt.xlabel('인구수')
plt.ylabel('CCTV 개수')
plt.grid()
plt.colorbar()
plt.show()

# %%
600000 * 1.02
# Out:
# 612000.0
